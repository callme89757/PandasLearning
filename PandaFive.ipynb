# %%
import pandas as pd
from pyecharts.charts import Bar
from pyecharts.charts import Page, Pie
from pyecharts import options as opts
from pyecharts.charts import Map
import tushare as ts
f=open("D:/python/myprogram/PandaLearning/data/Task_4_lianjia_sale.csv",encoding='utf-8')
lianjia_data=pd.read_table(f,sep=',')
df1=pd.DataFrame(lianjia_data)

# %%
df_avg=round(df1.groupby('区域')['价格'].agg([('区域平均价格','mean')]).sort_values(by = '区域平均价格'))

# %%
lst_avg=df_avg['区域平均价格'].tolist()
lst_name=df_avg.index.values.tolist()
bar=Bar()
bar.add_xaxis(xaxis_data=lst_name)
bar.add_yaxis("房价",lst_avg)
bar.set_global_opts(title_opts=opts.TitleOpts(
title="上海各区域平均价格"
))
bar.reversal_axis()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e2d5d97a04fb496f8c96533c36af68bd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e2d5d97a04fb496f8c96533c36af68bd = echarts.init(
#                     document.getElementById('e2d5d97a04fb496f8c96533c36af68bd'), 'white', {renderer: 'canvas'});
#                 var option_e2d5d97a04fb496f8c96533c36af68bd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
lst_name_new = [i+'区' if i!='浦东' else i+'新区' for i in df_avg.index.tolist()]
list1=[[lst_name_new[i],lst_avg[i]] for i in range(len(lst_name))]
map_shanghai=Map()
map_shanghai.set_global_opts(
    title_opts=opts.TitleOpts(title="上海各区平均房价"),
    visualmap_opts=opts.VisualMapOpts(max_=100000)
)
map_shanghai.add("上海各区平均房价",list1,maptype='上海')
map_shanghai.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
map_shanghai.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '上海':'https://assets.pyecharts.org/assets/maps/shanghai'
#         }
#     });
# </script>
#
#         <div id="8f4911c780354b45a4056e0d3fdbf12c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '上海'], function(echarts) {
#                 var chart_8f4911c780354b45a4056e0d3fdbf12c = echarts.init(
#                     document.getElementById('8f4911c780354b45a4056e0d3fdbf12c'), 'white', {renderer: 'canvas'});
#                 var option_8f4911c780354b45a4056e0d3fdbf12c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
aFrame=ts.get_area_classified().groupby('area')['name'].agg([('公司数量','count')])
lst_num=aFrame['公司数量'].tolist()  
lst_name= [i+'古' if i =='内蒙' else i for i in aFrame.index.values.tolist()]
list2=[[lst_name[i],lst_num[i]] for i in range(len(lst_name))]
map_china=Map()
map_china.set_global_opts(
    title_opts=opts.TitleOpts(title="中国各省上市公司数量"),
    visualmap_opts=opts.VisualMapOpts(max_=500)
)
map_china.add("中国各省上市公司数量",list2,maptype='china')
#map_china.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
map_china.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="3b649b20e7544ff5ab950f923c78bf55" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_3b649b20e7544ff5ab950f923c78bf55 = echarts.init(
#                     document.getElementById('3b649b20e7544ff5ab950f923c78bf55'), 'white', {renderer: 'canvas'});
#                 var option_3b649b20e7544ff5ab950f923c78bf55 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...
